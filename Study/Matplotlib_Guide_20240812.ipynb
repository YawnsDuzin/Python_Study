# %% [markdown]
# # Matplotlib Tutorial - 파이썬으로 데이터 시각화하기
#  - 부제 : MATPLOTLIB
#   - Data Visualization with Python
#     - 40여 개의 주제, 140개 이상의 예제와 함께 파이썬의 대표적인 데이터 시각화 라이브러리 Matplotlib의 기초를 소개합니다.
# - 김민회 지움 / 유페이퍼

# %% [markdown]
# ## Matplotlib 소개와 설치

# %% [markdown]
# ### Matplotlib 소개
# - Matplotlib은 데이터 시각화와 2D 그래프 플롯에 사용되는 파이썬 라이브러리 입니다.
# - Matplotlib을 이용하면 꺽은선 그래프, 막대 그래프, 히스토그램 등 다양한 유형의 그래프를 몇 줄의 코드로 간편하게 그리고, 데이터 곡선, 눈금, 범례, 제목 등 다양한 그래프 구성 요소를 커스터마이징 할 수 있습니다.

# %% [markdown]
# ### Matplotlib 설치하기
# 1) 공식 배포판
#   - 아래의 명령어로 공식 배포판을 설치할 수 있습니다.
#   ```python
#   python -m pip install -U pip
#   python -m pip install -U matplotlib
#   ```
# 2) Third-party 배포판 설치하기
#   - 과학용 파이썬 배포판
#     - Matplotlib 라이브러리와 함께 여러 유용한 데이터 과학 패키지를 포함하는 Anaconda도 Matplotlib을 사용하는 좋은 방법이 될 수 있습니다.

# %% [markdown]
# ## Matplotlib 기본 사용
# - Matplotlib 라이브러리를 이용해서 그래프를 그리는 기본적인 방법에 대해 소개합니다.

# %% [markdown]
# ### 1) 기본사용
# - matplotlib.pyplot 모듈은 MATLAB과 비슷하게 명령어 스타일로 동작하는 함수들의 모음입니다. matplotlib.pyplot 모듈의 각각의 함수를 사용해서 간편하게 그래프를 만들고 변화를 줄 수 있습니다.
# - 예를 들어, 그래프 영역을 만들고, 몇 개의 선을 표현하고, 레이블로 꾸미는 등의 작업을 할 수 있습니다.

# %% [markdown]
# ### 2) 기본 그래프 그리기

# %% [markdown]
# - matplotlib.pyplot 모듈의 plot() 함수에 하나의 숫자 리스트를 입력함으로써 아래와 같은 그래프가 그려집니다.
# - plot() 함수는 **리스트를 하나만 입력 시, 리스트의 값들이 y값들이라고 가정**하고, x 값들 ([0, 1, 2, 3]) 을 자동으로 만들어 냅니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])    # y-values [1, 2, 3, 4]
# plt.show()

# %% [markdown]
# - 아래와 같이 두 리스트를 입력하면, x와 y값을 그래프로 나타낼 수 있습니다.

# %%
# x-values : [1, 2, 3, 4]
# y-values : [1, 4, 9, 16]
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %% [markdown]
# ### 3) 스타일 지정하기

# %% [markdown]
# - 형식 문자열 'ro'는 빨간색('red')의 원형('o') 마커를 의미합니다.
#   - 또한, 예를 들어 'b-' 는 파란색('blue')의 실선('-')를 의미합니다.
# - axis() 함수는 축의범위를 지정할 수 있습니다.
#   - axis([x_min, x_max, y_min, y_max])

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
#plt.show()
# Out:
# (0.0, 6.0, 0.0, 20.0)

# %% [markdown]
# ### 4) 여러 개의 그래프 그리기

# %% [markdown]
# - Matplotlib 에서는 일반적으로 Numpy Array 를 이용하게 되는데, 사실 Numpy Array를 사용하지 않더라도 모든 시퀀스 자료형은 내부적으로 Numpy Array로 변환됩니다.
# - 이 예제는 다양항 스타일을 갖는 여러 개의 곡선을 하나의 그래프로 나타냅니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0., 5., 0.2)

plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
#plt.show()

# %% [markdown]
# ## Matplotlib 숫자 입력하기
# - matplotlib.pyplot 모듈의 plot() 은 선(Line) 또는 마커(Marker) 그래프 그리기에 사용되는 함수입니다.
# - plot() 함수에 y값을 리스트 형태로 입력하면 그림과 같은 꺽은선 그래프가 그려집니다.

# %% [markdown]
# ### 1) 기본 사용

# %% [markdown]
# - 이 세 줄의 코드는 간단한 그래프를 하나 띄웁니다. plot([2, 3, 5, 10]) 와 같이 하나의 리스트 형태로 값들을 입력하면 y값으로 인식합니다.
# - plot((2, 3, 5, 10)) 또는 plot(np.array([2, 3, 4, 10])와 같이 파이썬 튜플 또는 Numpy Array 형태로도 데이터를 입력할 수 있습니다.
#   - x값은 기본적으로 [0, 1, 2, 3]이 되어서, 점 (0,2), (1,3), (2,5), (3,10)을 잇는 아래와 같은 꺽은선 그래프가 나타납니다.

# %%
import matplotlib.pyplot as plt

plt.plot([2, 3, 5, 10])
# plt.show()

# %% [markdown]
# ### 2) x,y값 입력하기

# %% [markdown]
# - plot() 함수에 두 개의 리스트를 입력하면 순서대로 x, y값들로 인식해서, 점 (1,2), (2,3), (3,5), (4,10)을 잇는 꺽은선 그래프가 나타납니다.

# %%
import matplotlib.pyplot as plt

# x_values : [1, 2, 3, 4]
# y_values : [2, 3, 5, 10]
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.show()

# %% [markdown]
# ### 3) 레이블이 있는 데이터 플롯하기

# %% [markdown]
# - 파이썬 딕셔너리와 같이 레이블이 있는 데이터를 그래프로 나타낼 수 있습니다.
# - 예제에서와 같이 먼저 plot() 함수에 데이터의 레이블 (딕셔너리의 키)을 입력해주고, data 파라미터에 딕셔너리를 지정해줍니다.

# %%
import matplotlib.pyplot as plt

data_dict = {'data_x' : [1, 2, 3, 4, 5], 'data_y' : [2, 3, 5, 10, 8]}

plt.plot('data_x', 'data_y', data = data_dict)
# plt.show()

# %% [markdown]
# ## Matplotlib 축 레이블 설정하기
# - matplotlib.pyplot 모듈의 xlabel(), ylabel() 함수를 사용하면, 그래프의 X,Y축에 대한 레이블을 표시할 수 있습니다.

# %% [markdown]
# ### 1) 기본사용

# %% [markdown]
# - **xlabel(), ylabel()** 함수에 문자열을 입력하면, 아래 그림과 같이 각각의 축에 레이블이 표시됩니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')  # x축 레이블
plt.ylabel('Y-Axis')  # y축 레이블
# plt.show()
# Out:
# Text(0, 0.5, 'Y-Axis')

# %% [markdown]
# ### 2) 여백 지정하기

# %% [markdown]
# - xlabel(), ylabel() 함수의 labelpad 파라미터는 축 레이블의 여백(Padding)을 지정합니다.
# - 아래에서는, x축 레이블에 대해서 15pt, y축 레이블에 대해서 20pt만큼의 여백을 지정했습니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])

plt.xlabel('X-Axis', labelpad = 15)
plt.ylabel('Y-Axis', labelpad = 20)
plt.show()

# %% [markdown]
# ### 3) 폰트 설정하기

# %% [markdown]
# - xlabel(), ylabel() 함수의 fontdict 파라미터를 사용하면, 축 레이블의 폰트 스타일을 설정할 수 있습니다.
# - 예제 에서는, 'family', 'color', 'weight', 'size'와 같은 속성을 사용해서 축 레이블 텍스트를 설정했습니다.
#
# - 주요한 속성에 대한 설명과 옵션은 아래 표를 참고하세요
#
# |Property|Description|Option|
# |:---:|:---|:---|
# |alpha|텍스트의 투명도|0.0 ~ 1.0 (float)|
# |color|텍스트의 색상|Any Matplotlib color|
# |family|텍스트의 글꼴|FONTNAME \| 'serif' \| 'sans-serif' \| 'cursive' \| 'fantasy' \| 'monospace'  |
# |rotation|텍스트의 회전각|angle in degrees \| 'vertical' \| 'horizontal'|
# |size|텍스트의 크기|size of points \| 'xx-small' \| 'x-small' \| 'small' \| 'medium' \| 'large' \| 'x-large' \| 'xx-large'|
# |weight|텍스트의 굵기|a numeric value n range 0-1000 \| 'ultralight' \| 'light' \| 'normal' \| 'regular' \| 'book' \| 'medium' \| 'roman' \| 'semibold' \|'demibold' \| 'demi' \| 'bold' \| 'heavy' \| 'extra bold' \| 'black'|

# %%
import matplotlib.pyplot as plt

font1 = {'family' : 'serif','color' : 'b', 'weight' : 'bold', 'size' : 14}
font2 = {'family' : 'fantasy', 'color' : 'deeppink', 'weight' : 'normal', 'size' : 'xx-large'}

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad = 15, fontdict = font1)
plt.ylabel('Y-Axis', labelpad = 20, fontdict = font2)
plt.show()

# %% [markdown]
# ### 4) 위치 지정하기

# %% [markdown]
# - xlabel() 함수의 loc 파라미터는 x축 레이블의 위치를 지정합니다.
#   - {'left', 'center', 'right'}
# - ylabel() 함수의 loc 파라미터는 y축 레이블의 위치를 지정합니다.
#   - {'bottom', 'center', 'top'}
#
# ```※ 이 파라미터는 Matplotlib 3.3 버전 이후부터 적용되었습니다.```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', loc = 'right')
plt.ylabel('Y-Axis', loc = 'top')
# plt.show()
# Out:
# Text(0, 1, 'Y-Axis')

# %% [markdown]
# ## Matplotlib 범례 표시하기
# - 범례(Legend)는 그래프에 데이터의 종류를 표시하기 위한 텍스트입니다.
# - matplotlib.pyplot 모듈의 legend() 함수를 사용해서 그래프에 범례를 표시할 수 있습니다.

# %% [markdown]
# ### 1) 기본 사용

# %% [markdown]
# - 그래프 영역에 범례를 나타내기 위해서는
#   - 우선 plot() 함수에 label 문자열을 지정하고,
#   - matplotlib.pyplot 모듈의 legend() 함수를 호출합니다.
# - 아래와 같이 그래프의 적절한 위치에 데이터를 설명하는 범례가 나타납니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = 'Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()

plt.show()

# %% [markdown]
# ### 2) 위치 지정하기

# %% [markdown]
# - legend() 함수의 loc 파라미터를 이용해서 범례가 표시될 위치를 설정할 수 있습니다.
#   - loc 파라미터를 숫자 쌍 튜플로 지정하면, 해당하는 위치에 범례가 표시됩니다.
#     - loc=(0.0, 0.0)은 데이터 영역의 왼쪽 아래
#     - loc=(1.0, 1.0)은 데이터 영역의 오른쪽 위 입니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = 'Price ($')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc = (0.0, 0.0))      # 데이터 영역의 왼쪽 아래
# plt.legend(loc = (0.5, 0.5))
plt.legend(loc = (1.0, 1.0))        # 데이터 영역의 오른쪽 위
# plt.show()

# %% [markdown]
# - loc 파라미터는 예제와 같이 문자열로 지정할 수도 있고, 숫자 코드를 사용할 수도 있습니다.
#   - loc = 'lower right'와 같이 지정하면 아래와 같이 오른쪽 아래에 범례가 표시됩니다.
#
# - 위치 지정 문자열과 코드는 아래의 표를 참고하세요
#
# |Location String|Location Code|Description|
# |:---:|:---|:---|
# |'best'|0|그래프의 최적의 위치에 표시합니다.(디폴트)|
# |'upper right'|1|그래프의 오른쪽 위에 표시합니다.|
# |'upper left'|2|그래프의 왼쪽 위에 표시합니다.|
# |'lower left'|3|그래프의 왼쪽 아래에 표시합니다.|
# |'lower right'|4|그래프의 오른쪽 아래에 표시합니다.|
# |'right'|5|그래프의 오른쪽에 표시합니다.|
# |'center left'|6|그래프의 왼쪽 가운데에 표시합니다.|
# |'center right'|7|그래프의 오른쪽 가운데에 표시합니다.|
# |'lower center'|8|그래프의 가운데 아래에 표시합니다.|
# |'upper center'|9|그래프의 가운데 위에 표시합니다.|
# |'center'|10|그래프의 가운데에 표시합니다.|

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = 'Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### 3) 열 개수 지정하기

# %% [markdown]
# - legend() 함수의 ncol 파라미터는 범례에 표시될 텍스트의 열의 개수를 지정합니다.
# - 기본적으로
#   - 아래 그림과 같이 범례 텍스트는 1개의 열로 표시되며,
#   ![image.png](data:image/png;base64,...)
#   - ncol=2로 지정하면 아래 그림과 같이 표시됩니다.
#   ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = 'Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label = 'Demand (#)')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

# plt.legend(loc = 'best')                # ncol = 1
plt.legend(loc = 'best', ncol = 2)        # ncol = 2
# plt.show

# %% [markdown]
# ### 4) 폰트 크기 지정하기

# %% [markdown]
# - legend() 함수의 fontsize 파라미터는 범례에 표시될 폰트의 크기를 지정합니다.
#   - lengend(범례)의 fontsize = 14 로 설정 시, 아래와 같이 표시됩니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = 'Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label = 'Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc = 'best', ncol = 2, fontsize = 14)

# %% [markdown]
# ### 5) 범례 테두리 꾸미기

# %% [markdown]
# - frameon 파라미터는 범례 텍스트 상자의 테두리를 표시할지 여부를 지정합니다.
#   - frameon = False 로 지정하면 테두리가 표시되지 않습니다.
# - shadow 파라미터를 사용해서 텍스트 상자에 그림자를 표시할 수 있습니다.
# - 이 외에도, facecolor, edgecolor, borderpad, labelspacing 과 같은 다양한 파라미터가 있습니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = 'Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label = 'Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc = 'best', ncol = 2, fontsize = 14, frameon = True, shadow = True)

# %% [markdown]
# ## Matplotlib 축 범위 지정하기
# - matplotlib.pyplot 모듈의 xlim(), ylim(), axis() 함수를 사용하면, 그래프의 X,Y축이 표시되는 범위를 지정할 수 있습니다.
#   - xlim() : x축이 표시되는 범위를 지정하거나 반환합니다.
#   ```python
#   plt.xlim(xmin, xmax)
#   plt.xlim((xmin, xmax))
#   plt.xlim([xmin, xmax])
#   ```
#   - ylim() : y축이 표시되는 범위를 지정하거나 반환합니다.
#   ```python
#   plt.ylim(ymin, ymax)
#   plt.ylim((ymin, ymax))
#   plt.ylim([ymin. ymax])
#   ```
#   - axis() : x,y축이 표시되는 범위를 지정하거나 반환합니다.
#   - 그래프의 축의 범위를 지정하고, 확인하는 방법에 대해 소개합니다.

# %% [markdown]
# ### 1) 기본사용 - xlim(), ylim()
# - xlim() 함수에 xmin, xmax 값을 각각 입력하거나, 리스트 또는 튜플의 형태로 입력합니다.
# - ylim() 함수에 ymin, ymax 값을 각각 입력하거나, 리스트 또는 튜플의 형태로 입력합니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])        # X축의 범위 : [x_min, x_max]
plt.ylim([0, 20])       # Y축의 범위 : [y_min, y_max]
# Out:
# (0.0, 20.0)

# %% [markdown]
# ### 2) 기본 사용 = axis()
# - axis() 함수에 [xmin, xmax, ymin, ymax]의 형태로 x,y축의 범위를 지정할 수 있습니다.
# - axis() 함수에 입력한 리스트(또는 튜플)는 반드시 네 개의 값 (xmin, xmax, ymin, ymax)이 있어야 합니다.
#   - 입력 값이 없으면 데이터에 맞게 자동으로 범위를 지정합니다.
#
# ```python
# plt.axis((xmin, xmax, ymin, ymax))
# plt.axis([xmin, xmax, ymin, ymax])
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20])     # x,y축의 범위 : [xmin, xmax, ymin, ymax]
# Out:
# (0.0, 5.0, 0.0, 20.0)

# %% [markdown]
# ### 3) 옵션 지정하기
# - axis() 함수는 아래와 같이 축에 관한 다양한 옵션을 제공합니다.
# ```
# 'on' | 'off' | 'equal' | 'scaled' | 'tight' | 'auto' | 'normal' | 'image' | 'square'
# ```
#
# - 'square'로 지정했을때는 축 길이가 동일하게 아래와 같이 표시됩니다.
#
# ![image.png](data:image/png;base64,...)
#
# - 'scaled'로 지정했을때는 x,y축이 같은 스케일로 표시됩니다.
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

# plt.axis('square')
plt.axis('scaled')
# Out:
# (0.85, 4.15, 1.6, 10.4)

# %% [markdown]
# ### 4) 축 범위 얻기
# ```python
# xmin, xmax = plt.xlim()
# ymin, ymax = plt.ylim()
# xmin, xmax, ymin, ymax = plt.axis()
# ```
# - xlim(), ylim() 함수는 그래프 영역에 표시되는 x축, y축의 범위를 각각 반환합니다.
# - axis() 함수는 그래프 영역에 표시되는 x,y축의 범위를 반환합니다.

# %% [markdown]
# 아래의 예제 그림에서 x축은 0.85 에서 4.15, y축은 1.6에서 10.4 범위로 표시되었음을 알 수 있습니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range)
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 4.15, 1.6, 10.4)

# %% [markdown]
# ## Matplotlib 선 종류 지정하기
# - 데이터를 표현하기 위해 그려지는 선의 종류를 지정하는 방법을 소개합니다.
# - 선 종류를 나타내는 문자열 또는 튜플을 이용해서 다양한 선의 종류를 구현할 수 있습니다.

# %% [markdown]
# ### 1) 기본사용 (포맷 문자열)
# - Matplotlib 에서 선의 종류를 지정하는 가장 간단한 방법은 포맷 문자열을 사용하는 것입니다.
# - '-'(Solid), '--'(Dashed), ':'(Dotted), '-.'(Dash-dot) 과 같이 네 가지 종류를 선택할 수 있습니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], '-', color = 'C0', label = 'Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color = 'C0', label = 'Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color = 'C0', label = 'Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color = 'C0', label = 'Dash-dot')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc = 'upper right', ncol = 4)

# %% [markdown]
# ### 2) linestyle 지정하기
# - plot() 함수의 linestyle 파라미터 값을 직접 지정할 수 있습니다.
# - 포맷 문자열과 같이 'solid', 'dashed', 'dotted', 'dashdot' 네 가지의 선 종류를 지정할 수 있습니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle = 'solid', color = 'C0', label = "'Solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle = 'dashed', color = 'C0', label = "'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle = 'dotted', color = 'C0', label = "'dotted'")
plt.plot([1, 2, 3], [1, 1 ,1], linestyle = 'dashdot', color = 'C0', label = "'dashdot'")

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc = 'upper right', ncol = 4)
plt.tight_layout()

# %% [markdown]
# ### 3) 튜플 사용하기
# - 튜플을 사용해서 선의 종류를 커스터마이즈 할 수 있습니다.
#   - 예를 들어,
#     - (0, (1, 1)) 는 'dotted'
#     - (0, (5, 5)) 는 'dashed'
#     - (0, (3, 5, 1, 5)) 는 'dashdotted'

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle = (0, (1, 1)), color = 'C0', label = '(0, (1, 1))')
plt.plot([1, 2, 3], [3, 3, 3], linestyle = (0, (1, 5)), color = 'C0', label = '(0, (1, 5))')
plt.plot([1, 2, 3], [2, 2, 2], linestyle = (0, (5, 1)), color = 'C0', label = '(0, (5, 1))')
plt.plot([1, 2, 3], [1, 1, 1], linestyle = (0, (3, 5, 1, 5)), color = 'C0', label = '(0, (3, 5, 1, 5))')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc = 'upper right', ncol = 4)
plt.tight_layout()

# %% [markdown]
# ## Matplotlib 마커 지정하기
# - 특별한 설정이 없으면 그래프가 실선으로 그려지지만, 위의 그림과 같은 마커 형태의 그래프를 그릴 수 있습니다.

# %% [markdown]
# ### 1) 기본사용
# - plot() 함수에 숫자 데이터와 함께 'bo'를 입력해주면 그래프가 파란색의 원형 마커로 표시됩니다.
#   - 'b'는 blue, 'o'는  circle 을 나타내는 문자입니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %% [markdown]
# ### 2) 선/마커 동시에 나타내기
# - 아래 그림과 같이 실선 또는 점선과 마커가 함께 표시됩니다.
#   - 'bo-'는 파란색의 원형 마커와 실선(Solid line)을 의미합니다.
#   - 'bo--'는 파란색의 원형 마커와 점선(Dashed line)을 의미합니다.

# %%
import matplotlib.pyplot as plt

# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')
