# %% [markdown]
# #1장. 캐글 소개

# %% [markdown]
# ##섹션01. 캐글이란 무엇인가

# %% [markdown]
# ###캐글이란

# %% [markdown]
# ###캐글링하기

# %% [markdown]
# ##섹션02. 캐글 활용 사례

# %% [markdown]
# ##섹션03. 다양한 경진 대회

# %% [markdown]
# #2장. 캐글 시작하기

# %% [markdown]
# ##섹션04. 캐글 첫걸음

# %% [markdown]
# ##섹션05. 캐글 컨트리뷰터 되기

# %% [markdown]
# #3장. 노트북 자유자재로 다루기

# %% [markdown]
# ##섹션06. 노트북

# %% [markdown]
# ##섹션07. 노트북 사용하기

# %% [markdown]
# ##섹션08. 노트북 능숙하게 다루기

# %% [markdown]
# #4장. 캐글의 경진 대회

# %% [markdown]
# ##섹션09. 경진 대회와 노트북

# %% [markdown]
# ##섹션10. 다양한 경진 대회

# %% [markdown]
# ##섹션11. 경진 대회의 세부 사항

# %% [markdown]
# #5장. 캐글 마스터 지향하기

# %% [markdown]
# ##섹션12. 경진 대회 규칙 이해하기

# %% [markdown]
# ##섹션13. 데이터를 더 잘 이해하기

# %% [markdown]
# ##섹션14. 최신 기술 살펴보기

# %% [markdown]
# ##섹션15. 캐글 데이터 세트와 API 활용하기

# %% [markdown]
# #부록-캐글에서 자주 사용하는 머신러닝 라이브러리와 프레임워크

# %% [markdown]
# ##섹션16. LightGBM 사용하기

# %% [markdown]
# ##섹션17. fast.ai 사용하기

# %% [markdown]
# # 참고 사이트
# - 페이스북 캐글 코리아 그룹
#   - https://www.facebook.com/groups/KaggleKoreaOpenGroup
# - 캐글 코리아 블로그
#   - https://kaggle-kr.tistory.com/
# - Kaggle-knowhow
#   - https://github.com/zzsza/Kaggle-knowhow
# - 한국인을 위한(파이썬) 캐글 튜토리얼
#   - https://github.com/seriousran/kaggle-for-korean
#
#   - https://github.com/dybooksIT/kaggle-guide

# %%
import seaborn as sns
import pandas as pd

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('dowjones')
df.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45
