# %% [markdown]
# # 구글드라이브 Mount

# %%
from google.colab import drive
drive.mount('/gdrive')
# drive.mount('/content/drive')
# Out:
# Mounted at /gdrive

# %%
# 나의 루트 경로 설정
dir_dataset = '/content/drive/MyDrive/_github/DataSet'

# %%
# 라이브러리 임포트
import os
import numpy as np
import pandas as pd
import chardet

# 사용자 정의함수 경로 설정
import sys

#sys.path.append("G:/내 드라이브/Source/_Custom_Function")
sys.path.append('/content/drive/MyDrive/_github/Python_DataAnalysis/Python_DataAnalysis/_Custom_Function')
# 사용자 정의함수 불러오기
import time

import folium

import ExcelFile_Read as er
import ExcelFile_EDA as ee
