# %% [markdown]
# # 1. 데이터 수집과 크롤링 개념 소개

# %% [markdown]
# ##1.1. 데이터 수집의 개념

# %% [markdown]
# - 데이터 수집이란?
#   - 데이터 수집은 정보를 수집하고 기록하는 과정
# - 데이터의 중요성
#   - 의사결정 지원
#     1. 데이터는 정확한 정보를 기반으로 한 의사 결정을 가능하게 함.
#     2. 예측분석, 마케링 전략 수립, 재무 계획 등 다양한 분야에서 중요한 역할을 지원
#       - 예) 기업은 예측 분석을 통해 다음 분기의 매출을 예상하고, 이에 따른 생산 계획을 수립
#   - 경쟁력 확보
#     - 데이터 분석을 통해 시장 동향을 파악하고 경쟁력을 유지할 수 있게 함.
#       - 예) 소셜 미디어 데이터를 분석하여 제품의 인지도를 높이고 타겟 마케팅을 통해 새로운 고객을 확보
# - 활용 예시
#   - 비즈니스
#     - 고객 행동 분석을 통한 개인화된 마케팅 전략 수립
#       - 예) 고객의 구매이력, 웹사이트 방문 기록, 소셜 미디어 활동 데이터를 분석하여 각 고객에게 맞춤형 광고 메시지 제공
#   - 연구
#     - 실험 결과 데이터를 분석하여 연구 성과를 평가
#       - 예) 의약품 개발 과정에서 실험 데이터를 통해 효능과 부작용을 평가하고, 이를 토대로 향후 연구 방향을 설정
#   - 정부
#     - 공공 데이터를 분석하여 정책 결정에 반영
#       - 예) 인구 통계 데이터를 기반으로 한 지역 별 교육 인프라 투자 계획 수립하여 교육의 질을 향상

# %% [markdown]
# ##1.2. 웹 크롤링의 개념
# - 웹 크롤링이란?
#   - 인터넷 상에 존재하는 다양항 웹 페이지를 자동으로 탐색하여 정보를 수집하는 과정
#     - 웹 페이지의 데이터를 분석하거나 데이터베이스를 구착하기 위해 사용 됨.
# - 크롤러와 스크래퍼의 차이점
#   - **크롤러(Crawler)**
#     - **웹 크롤링을 실행하는 프로그램 또는 스크립트의 의미**
#     - 웹 페이지를 자동으로 방문하고 링크를 따라가며 데이터를 수집함
#       - 예) 네이버나 구글 검색 엔진의 크롤러는 웹 페이지를 수집하고, 이를 인덱싱하여 사용자에게 검색결과를 제공
#   - **스크래퍼(Scraper)**
#     - **특정 웹 페이지에서 필요한 데이터를 추출하는 도구를 의미**
#     - HTML구조를 분석하고, 원하는 데이터를 추출하여 저장하거나 분석에 활용
#       - 예) 가격 비교 사이트에서는 각 상품 페이지에서 가격과 설명을 추출하여 사용자에게 제공
# - 웹 크롤링의 작동 과정
#   1. 시작 URL에서 부터 시작하여 HTML 문서를 다운로드
#   2. 링크를 추출하고, 다음으로 이동할 URL을 결정하여 저장구조(큐)에 저장
#   3. 각 URL을 방문하고 해당 웹 페이지의 내용을 추출
#   4. 추출된 데이터는 필터링이나 전처리 후 저장하거나 분석에 활용됨.
# - 적용 사례
#   - 뉴스 집계 사이트
#     - 다양한 뉴스 사이트에서 최신기사를 수집하여 사용자에게 제공함.
#   - 부동산 정보 수집
#     - 부동산 웹 사이트에서 매매 및 임대정보를 수집하여 시세 추이를 분석하고 비교
#   - SNS 데이터 분석
#     - 소셜 미디어에서 특정 키워드의 사용량 및 트렌드를 분석하여 마케팅 전략을 활용

# %% [markdown]
# ##1.3. 데이터 수집과 웹 크롤링의 윤리적, 법적 쟁점
# - 데이터 수집 시 고려해야 할 윤리적 문제
#   - 개인정보 보호
#     - 개인 식별 정보를 포함한 데이터를 수집 시 개인정보 보호법에 따른 규제를 준수해야 함.
#       - 예) 사용자 동의 없이 개인 식별 가능 정보를 수집하는 것은 불법일 수 있음.
#   - 데이터 사용 목적의 투명성
#     - 수집한 데이터를 어떻게 사용하고, 누구와 공유하는지 명확히 고지해야 함.
#       - 예) 수집된 데이터가 마케팅 목적이나 연구에 사용될 경우, 목적을 명확히 하고 사용 동의를 받아야 함.
#   - 데이터 정확성과 신뢰성
#     - 수집한 데이터가 정확하고 신뢰할 수 있는지 확인해야 함.
#       - 예) 잘못된 정보를 공개할 경우 사용자에게 피해를 줄 수 있으므로 정확성 검토가 필요함.
# - 로봇 배제 표준(Robots.txt)에 대한 이해
#   - 웹 사이트 소유자가 웹 크롤러가 특정 페이지나 디렉토리에 방문하지 않도록 제어하는 표준
#   - 구조 및 작동 방식
#     - Robots.txt 파일
#       - 웹 사이트 루트 디렉토리에 위치한 텍스트 파일로, 크롤러에게 허용되는 경로와 제한되는 경로를 명시함.
#     - 방문 권한 지정
#       - 특정 경로에 대해 크롤러에게 허용 또는 거부 권한을 부여하여 웹 사이트 로딩 속도를 향상시키고 서버 부하를 줄임.
# - 고려사항
#   - 법적 규제 준수
#     - 데이터 수집과 관련된 법적 요구사항과 규제를 준수
#       - 예) 개인정보 보호법 시행으로 개인정보 보호에 관한 엄격한 규제
#   - 프로토콜 존중
#     - 웹 사이트가 웹 크롤러에게 명시한 제한을 존중하고 준수해야 함.
#     - 웹 사이트 소유자의 의도와 서버 부하관리를 위한 필수 조치

# %% [markdown]
# # 실습 환경 구축

# %% [markdown]
#  - Python 다운로드 및 설치
#   - 공식 웹사이트에서 다운로드
#     - https://www.python.org/downloads/
#   - 설치 파일 실행 후, 설치완료
#     - **path 체크 필수**
#       - **※ 이거 안한경우, 삭제하고 재설치 하는게 나음.**
#   - cmd 콘솔창에서 파이썬 버전 확인
#     - python --version

# %% [markdown]
# ##2.1 Visual Studio Code 설치
# -  VS Code 란?
#   - 마이크로소프트에서 개발한 통합 개발 환경(IDE)을 제공하는 도구
#     - 다양한 언어를 지원하며 빠르고 효율적인 코딩 환경을 제공
#     - Window, maxOS, Linux에서 모두 사용가능
#     - 수 많은 확장 기능을 통해 기능 확장 가능
# - 설치 방법
#   - VS Code 공식 웹사이트에서 다운로드
#     - https://code.viisualstudio.com/
#   - 설치 파일 실행 후, 설치완료
# - 확장 기능 설치
#   - **Python extendsion for Visual Studio Code**
#   - **Jupyter**
#     - Jupyter Notebook 지원을 위한 기능
#     - 기존 Jupyter notebook 사용 방식 그대로 이용가능함.
#   - **Korean Language Pack for Visual Studio Code (한국어 지원)**
# - 설정
#   - AutoSave 설정

# %% [markdown]
# # 3.API를 이용한 데이터 수집

# %% [markdown]
# ##3.1 API 기본 개념 소개

# %% [markdown]
# - API 란 무엇인가?
#   - API(Application Programming Interface)의 약자로, 소프트웨어 애플리캐이션 간에 서로 통신할 수 있도록 만든 인터페이스를 의미함.
#     - 다른 애플리케이션이나 서비스에서 제공하는 기능을 외부에서 활용할 수 있게 함.
# - 특징
#   - 명세화
#     - 특정한 규칙과 명세에 따라 정의되어야 함.
#   - 재사용성
#     - 기존의 기능을 다른 애플리케이션에서 재사용할 수 있도록 하는 기능
#   - 추상화
#     - 내부 구현을 숨기고 필요한 기능에 집중할 수 있도록 도와 주는 기능
# - Open API의 기본 개념 소개
#   - Open API란?
#     - Open API는 누구나 접근하고 사용할 수 있도록 공개된 API를 의미함.
#     - 주로 기업이나 공공기관에서 데이터를 외부에 제공하기 위해 사용함.
#   - 특징
#     - 공개접근
#       - 누구나 접근할 수 있으며, 별도의 인증 절차를 거쳐 사용할 수 있음.
#     - 표준화된 규격
#       - REST, SOAP 등의 표준화된 규격을 따름
#     - 문서화
#       - API 사용 방법과 예제 코드가 포함된 문서가 제공되어야 함.
# - Open API 의 활용
#   - 공공데이터
#     - 정부 및 공공기관에서 제공하는 데이터(API)를 활용하여 새로운 서비스 개발
#       - 예) 기상청 API를 이용한 날씨 정보 제공 앱
#   - 소셜데이터
#     - 트위터, 페이스 북 등의 소셜 미디어 플랫폼에서 제공하는 API를 통해 사용자 데이터 수집 및 분석
#   - 금융데이터
#     - 금융기관에서 제공하는 API를 통해 실시간 금융 데이터 제공
#       - 예) 주식 시세 API를 이용한 주식 거래 앱
# - Open API 사용 시 유의사항
#   - 대부분의 Open API는 인증을 필요로 함.
#   - API호출에는 제한이 있을 수 있으며, 준수하지 않으면 사용이 제한 될 수 있음.
#   - API 제공자는 데이터 사용에 대한 정책을 명시하고 있으며, 이를 준수해야 함.

# %% [markdown]
# ##3.1.5. 공공 데이터 포털 API 이용하기

# %% [markdown]
# - 공공데이터 포털
#   - url : https://www.data.go.kr
#   - 회원가입 및 로그인
# - 식품의약품 안전처_식품 영양성분 정보
#   - 활용신청 => Open API 개발계정 신청 => 신청하면 승인

# %% [markdown]
# ##3.2. JSON 데이터 처리

# %% [markdown]
# ###JSON 데이터

# %% [markdown]
# - JSON 이란 무엇인가?
#   - JavaScript Object Notation 의 약자
#   - 데이터를 저장하고 전송하기 위해 사용하는 경량 데이터 교환 포맷
#   - 텍스트 기반으로 사람이 읽고 쓸 수 있으며, 기계가 분석하고 생성할 수 있음.
# - JSON의 특징
#   - 간결성
#     - 가독성이 좋고, 구조가 간결하여 데이터를 쉽게 이해할 수 있음.
#   - 가독성
#     - 사람과 기계 모두가 읽고 쓰기 쉽게 설계되어 있음.
#   - 유연성
#     - 객체와 배열을 사용하여 복잡한 데이터 구조를 쉽게 표현할 수 있음
#   - 호환성
#     - 대부분의 프로그래밍 언어에서 JSON을 쉽게 파싱하고 생성할 수 있는 라이브러리를 제공함.

# %% [markdown]
# ###JSON의 기본문법

# %% [markdown]
# - 키-값 쌍으로 데이터를 표현하며, 중첩된 구조를 가질 수 있음.
# - 주요 요소
#   - JSON 객체
#     - 중괄호 '{}'로 감싸고, 키-값 쌍으로 구성
#     ```
#     {
#         "name" : "John",
#         "age" : 30
#     }
#     ```
#   - JSON 배열
#     - 대괄호 '[]'로 감싸고, 쉼표로 구분된 값들의 리스트
#     - 배열의 인덱스는 0부터 시작
#     ```
#     [ "apple", "banana", "cherry" ]
#     ```
# - JSON 데이터 타입
#   - 기본자료형
#     - 객체(사전), 배열((리스트), 문자열, 숫자, Boolean, null
#   - Null은 빈 값을 나타냄.
#   - 리스트 마지막에 쉼표가 있으면 안됨.
#   - 객체의 키 값은 반드시 문자열
#
#   ```
#   obj = """
#   {"name" : "Wes",
#    "places_lived" : ["", "", ""],
#    "pet" : null,
#    "siblings" : [ {"name" : "Scott", "age" : 25, "pet" : "Zuko"},
#                   {"name" : "Katie", "age" : 33, "pet" : "Cisco"} ]
#
#   }
#   """
#   ```

# %% [markdown]
# ###JSON 예제코드

# %% [markdown]
# ```
# import json
# ```

# %%
import json

# %% [markdown]
# ####JSON 객체 생성

# %%
obj = """
{"name" : "Wes",
 "place_lived" : ["United States", "Spain", "Germany"],
 "pet" : null,
 "siblings" : [{"name" : "Scott", "age" : 25, "pet" : "Zuko"},
               {"name" : "Katie", "age" : 33, "pet" : "Cisco"}]
}
"""

# %%
print(type(obj))
print(obj)
# Out:
# <class 'str'>
#
# {"name" : "Wes",
#  "place_lived" : ["United States", "Spain", "Germany"],
#  "pet" : null,
#  "siblings" : [{"name" : "Scott", "age" : 25, "pet" : "Zuko"},
#                {"name" : "Katie", "age" : 33, "pet" : "Cisco"}]
# }

# %%
import json

# %% [markdown]
# #### JSON 데이터 읽고 쓰기

# %% [markdown]
# ##### json.loads()
# - json문자열을 파이썬 사전 객체로 디코딩

# %%
result = json.loads(obj)

print(type(result))     # <class 'dict'>
print(result)
# Out:
# <class 'dict'>
# {'name': 'Wes', 'place_lived': ['United States', 'Spain', 'Germany'], 'pet': None, 'siblings': [{'name': 'Scott', 'age': 25, 'pet': 'Zuko'}, {'name': 'Katie', 'age': 33, 'pet': 'Cisco'}]}

# %%
print('name : ', result['name'])
print('place_lived : ', result['place_lived'])
print('pet : ', result['pet'])
print('siblings : ', result['siblings'])
# Out:
# name :  Wes
# place_lived :  ['United States', 'Spain', 'Germany']
# pet :  None
# siblings :  [{'name': 'Scott', 'age': 25, 'pet': 'Zuko'}, {'name': 'Katie', 'age': 33, 'pet': 'Cisco'}]

# %%
print(result['siblings'][1]['name'])
print(result['siblings'][1]['age'])
print(result['siblings'][1]['pet'])
# Out:
# Katie
# 33
# Cisco

# %% [markdown]
# #####json.load()
# - 파일에서 읽은 json데이터를 파이썬 사전 객체로 디코딩

# %% [markdown]
# - 아래 형식의 sample.json 파일 생성
# ```
# {"name" : "Wes",
#  "place_lived" : ["United States", "Spain", "Germany"],
#  "pet" : null,
#  "siblings" : [{"name" : "Scott", "age" : 25, "pet" : "Zuko"},
#                {"name" : "Katie", "age" : 33, "pet" : "Cisco"}]
# }
# ```

# %%
json_file_path = 'sample.json'
with open(json_file_path, 'r', encoding='utf-8') as file:
  result2 = json.load(file)

print(type(result2))
print(result2)

# %%
print(result2['siblings'][0]['name'])
print(result2['siblings'][0]['age'])
print(result2['siblings'][0]['pet'])

# %%
result2['siblings'][1]['age'] = 30    # 나이를 30으로 변경

print(result2['siblings'])

# %% [markdown]
# #####json.dumps()
# - 파이썬 사전 객체를 json 문자열로 인코딩

# %%
new_result = json.dumps(result)

print(type(new_result))
print(new_result)
# Out:
# <class 'str'>
# {"name": "Wes", "place_lived": ["United States", "Spain", "Germany"], "pet": null, "siblings": [{"name": "Scott", "age": 25, "pet": "Zuko"}, {"name": "Katie", "age": 33, "pet": "Cisco"}]}

# %%
# a python object (dict)
x = {
    "name" : "John",
    "age" : 30,
    "city" : "New York"
}

y = json.dumps(x)

print('type(x) : ', type(x))
print('type(y) : ', type(y))
print(y)
# Out:
# type(x) :  <class 'dict'>
# type(y) :  <class 'str'>
# {"name": "John", "age": 30, "city": "New York"}

# %%
# Python 객체를 JSON 문자열로 변환하고 값을 출력합니다.
import json

print(json.dumps({"name" : "John", "Age" : 30}))
print(json.dumps(['apple', 'banana']))
print(json.dumps(('apple', 'banana')))
print(json.dumps('hello'))
print(json.dumps(42))
print(json.dumps(31.76))
print(json.dumps(True))
print(json.dumps(False))
print(json.dumps(None))
# Out:
# {"name": "John", "Age": 30}
# ["apple", "banana"]
# ["apple", "banana"]
# "hello"
# 42
# 31.76
# true
# false
# null

# %%
import json
x = {
    "name" : "John",
    "age" : 30,
    "married" : True,
    "divorced" : False,
    "children" : ("Ann", "Billy"),
    "pets" : None,
    "cars" : [
        {"model" : "BMW 230", "mpg" : 27.5},
        {"model" : "Ford Edge", "mpg" : 24.1}
    ]
}

print(json.dumps(x))
# Out:
# {"name": "John", "age": 30, "married": true, "divorced": false, "children": ["Ann", "Billy"], "pets": null, "cars": [{"model": "BMW 230", "mpg": 27.5}, {"model": "Ford Edge", "mpg": 24.1}]}

# %% [markdown]
# #####json.dump()
# - 파이썬 사전 객체를 json 파일로 인코딩
#   - indent : 들여쓰기

# %%
with open("newsample.json", 'w', encoding='utf-8') as file:
    json.dump(result1, file, indent = 4)

# %% [markdown]
# #####pandas.read_json()
# - 단순한 데이터 구조의 json 데이터 셋은 DataFrame 으로 변환할 수 있다.
#   - ※ 복잡한 구조의 json 데이터는 변환불가

# %% [markdown]
# - 아래 형식의 sample2.json 파일을 생성한다.
# ```
# [{"a" : 1, "b" : 2, "c" : 3},
#             {"a" : 4, "b" : 5, "c" : 6},
#             {"a" : 7, "b" : 8, "c" : 9}
# ]
# ```

# %%
import pandas as pd

data = pd.read_json('sample2.json')
data

# %% [markdown]
# #####DataFrame.to_json()
# - DataFrame에 저장 된 데이터를 json으로 저장

# %%
print(data.to_json())
print(data.to_json(orient='records'))

# %% [markdown]
# #####pandas.json_nomalize()
# - 복잡한 json 데이터는 json_nomalize() 를 이용해서 DataFrame으로 변환가능

# %%
df = pd.DataFrame(result)
df

# %%
print(df['place_lived'][0][0])
print(df['siblings'][0][0]['name'])

# %%
# pandas.json_nomalize()
import pandas as pd
import json

with open('sample.json', 'r') as file:
    data_dict = json.load(file)

df = pd.json_normalize(data_dict)

print(df)

# %% [markdown]
# ###JSON 실습

# %%
json_obj = """
{
    "employees": [
        {
            "name": "홍길동",
            "age": 30,
            "department": "SW개발부",
            "skills": [
                "Python",
                "JavaScript",
                "C++"
            ]
        },
        {
            "name": "김길동",
            "age": 25,
            "department": "마케팅부",
            "skills": [
                "쇼셜미디어마케팅",
                "컨텐트 개발"
            ]
        }
    ]
}
"""

# %%
import json
import pandas as pd

# %%
dict = json.loads(json_obj)

# %%
print(type(dict))
# Out:
# <class 'dict'>

# %%
data = dict['employees']
print(data)
print(type(data))
# Out:
# [{'name': '홍길동', 'age': 30, 'department': 'SW개발부', 'skills': ['Python', 'JavaScript', 'C++']}, {'name': '김길동', 'age': 25, 'department': '마케팅부', 'skills': ['쇼셜미디어마케팅', '컨텐트 개발']}]
# <class 'list'>

# %%
print(type(data[0]))
# Out:
# <class 'dict'>

# %%
for employee in data:
    print(f'name : {employee["name"]}')
    print(f'age : {employee["age"]}')
    print(f'department : {employee["department"]}')
    print(f'skills : {employee["skills"]}')
# Out:
# name : 홍길동
# age : 30
# department : SW개발부
# skills : ['Python', 'JavaScript', 'C++']
# name : 김길동
# age : 25
# department : 마케팅부
# skills : ['쇼셜미디어마케팅', '컨텐트 개발']

# %%
import pandas as pd

df = pd.read_json(dict['employees'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-5622cb4ae600> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_json(dict['employees'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     758         convert_axes = True
#     759
# --> 760     json_reader = JsonReader(
#     761         path_or_buf,
#     762         orient=orient,
#
# ...

# %%
import pandas as pd

df = pd.json_normalize(dict['employees'])
df
# Out:
#   name  age department                     skills
# 0  홍길동   30      SW개발부  [Python, JavaScript, C++]
# 1  김길동   25       마케팅부         [쇼셜미디어마케팅, 컨텐트 개발]

# %%
import pandas as pd

df1 = pd.json_normalize(dict)
df1
# Out:
#                                            employees
# 0  [{'name': '홍길동', 'age': 30, 'department': 'SW개...

# %%
#print(type(df1))
#print(df1)
print(df1['employees'])
print(df1['employees'][0])
print(df1['employees'][0][0])
print(df1['employees'][0][0]['name'])
# Out:
# 0    [{'name': '홍길동', 'age': 30, 'department': 'SW개...
# Name: employees, dtype: object
# [{'name': '홍길동', 'age': 30, 'department': 'SW개발부', 'skills': ['Python', 'JavaScript', 'C++']}, {'name': '김길동', 'age': 25, 'department': '마케팅부', 'skills': ['쇼셜미디어마케팅', '컨텐트 개발']}]
# {'name': '홍길동', 'age': 30, 'department': 'SW개발부', 'skills': ['Python', 'JavaScript', 'C++']}
# 홍길동

# %% [markdown]
# ## 3.3 Requests 라이브러리 소개 및

# %% [markdown]
# ###웹 API 사용하여 JSON 데이터
# - Requests 라이브러리
#   - 파이썬에서 HTTP 요청을 보내기 위해 널리 사용되는 라이브러리
#   - 간단하고 직관적인 인터페이스 제공하여 GET,POST,PUT,DELETE 등의 HTTP메소드 사용이 용이함.
#   - 주요특징
#     - 간단한 HTTP 요청/응답 처리
#     - 다양한 HTTP 메소드 지원 (GET/POST/PUT/DELETE 등)
#     - 요청 매개변수와 헤더 설정
#     - JSON 데이터 자동 파싱
#     - 타임아웃 및 예외처리 기능
#   - 라이브러리 설치
#   ```
#   pip install requests
#   ```
# - Requests 기본 사용법
#   - GET 요청 보내기
#     - 서버에 데이터를 요청할 때 get() 함수 사용
#     ```python
#     import requests
#     url = 'https://api.github.com/repos/pydata/pandas/milestones/28/labels'
#     response = requests.get(url)
#     if response.status_code == 200:
#       print(response.text)
#     else:
#       print(response.status_code
#     ```
#   - json 데이터 변환시 json() 함수
#
#   ```python
#   result = response.json()
#   print(result)
#   ```
#   - DataFrame 생성
#
#   ```python
#   import pandas as pd
#
#   issue_labels = pd.DataFrame(result)
#   issue_labels
#   ```

# %% [markdown]
# ###공공 데이터 API를 통한 JSON 데이터 처리

# %% [markdown]
# - 공공데이터 포털
#   - url : https://www.data.go.kr
# - "식품의약품 안전처_식품 영양성분 정보"
#   - 사이트 접속 후, "활용신청" 을 눌러서 API KEY를 받는다.

# %% [markdown]
# ###Request 예제코드 (Feat. 공공데이터)

# %%
# request 라이브러리 설치
# %pip install requests

# %%
import requests

# %% [markdown]
# ####척노리스 조크 API 사이트 접속

# %%
url = 'https://api.chucknorris.io/jokes/random'
response = requests.get(url)

if response.status_code == 200:
    print(response.text)
else:
    print(response.status_code)
# Out:
# {"categories":[],"created_at":"2020-01-05 13:42:21.795084","icon_url":"https://api.chucknorris.io/img/avatar/chuck-norris.png","id":"nbXV1JV0REa0rKTYqxVXTw","updated_at":"2020-01-05 13:42:21.795084","url":"https://api.chucknorris.io/jokes/nbXV1JV0REa0rKTYqxVXTw","value":"Just looking at a picture of Chuck Norris makes you more of a man."}

# %%
print(type(response))
print(type(response.text))
# Out:
# <class 'requests.models.Response'>
# <class 'str'>

# %%
result = response.json()
print(result)
print(type(result))
# Out:
# {'categories': [], 'created_at': '2020-01-05 13:42:21.795084', 'icon_url': 'https://api.chucknorris.io/img/avatar/chuck-norris.png', 'id': 'nbXV1JV0REa0rKTYqxVXTw', 'updated_at': '2020-01-05 13:42:21.795084', 'url': 'https://api.chucknorris.io/jokes/nbXV1JV0REa0rKTYqxVXTw', 'value': 'Just looking at a picture of Chuck Norris makes you more of a man.'}
# <class 'dict'>

# %%
print(result['categories'])
print(result['created_at'])
print(result['icon_url'])
print(result['id'])
print(result['updated_at'])
print(result['url'])
print(result['value'])
# Out:
# []
# 2020-01-05 13:42:21.795084
# https://api.chucknorris.io/img/avatar/chuck-norris.png
# nbXV1JV0REa0rKTYqxVXTw
# 2020-01-05 13:42:21.795084
# https://api.chucknorris.io/jokes/nbXV1JV0REa0rKTYqxVXTw
# Just looking at a picture of Chuck Norris makes you more of a man.

# %%
import pandas as pd

issue_labels = pd.DataFrame(result)
print(issue_labels)
# Out:
# Empty DataFrame
# Columns: [categories, created_at, icon_url, id, updated_at, url, value]
# Index: []

# %% [markdown]
# ####공공데이터 실습

# %% [markdown]
# ##### 바나나칩의 식품정보 가져오기

# %%
# Python3 샘플 코드 #
import requests

# 일반 인증키 (Decoding) 사용
apikey = 'CTYRyVuDwSNng8WPJCY6Lm0A9JtQXyNRYn+7lI8FhtdmOgAF5g3dKjtS6AVkxJGU+dJXoZ2cmlEwbt7r6H1QsA=='

url = 'http://apis.data.go.kr/1471000/FoodNtrIrdntInfoService1/getFoodNtrItdntList1'

# 바나나칩
params ={'serviceKey' : apikey,
         'desc_kor' : '바나나칩',
         'pageNo' : '1',
         'numOfRows' : '3',
         'bgn_year' : '2017',
         'animal_plant' : '(유)돌코리아',
         'type' : 'json' }

response = requests.get(url, params=params)

if response.status_code == 200:
    result = response.json()
    print(result)
else:
    print('실패 : ', response.status_code)
# Out:
# {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}, 'body': {'pageNo': 1, 'totalCount': 1, 'numOfRows': 3, 'items': [{'DESC_KOR': '바나나칩', 'SERVING_WT': '30', 'NUTR_CONT1': '49.50', 'NUTR_CONT2': '5.40', 'NUTR_CONT3': '0.30', 'NUTR_CONT4': '3.00', 'NUTR_CONT5': '3.30', 'NUTR_CONT6': '0.60', 'NUTR_CONT7': '0.00', 'NUTR_CONT8': '2.70', 'NUTR_CONT9': '0.00', 'BGN_YEAR': '2017', 'ANIMAL_PLANT': '(유)돌코리아'}]}}

# %%
print(result)
print(type(result))
# Out:
# {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}, 'body': {'pageNo': 1, 'totalCount': 1, 'numOfRows': 3, 'items': [{'DESC_KOR': '바나나칩', 'SERVING_WT': '30', 'NUTR_CONT1': '49.50', 'NUTR_CONT2': '5.40', 'NUTR_CONT3': '0.30', 'NUTR_CONT4': '3.00', 'NUTR_CONT5': '3.30', 'NUTR_CONT6': '0.60', 'NUTR_CONT7': '0.00', 'NUTR_CONT8': '2.70', 'NUTR_CONT9': '0.00', 'BGN_YEAR': '2017', 'ANIMAL_PLANT': '(유)돌코리아'}]}}
# <class 'dict'>

# %%
for dic in result:
    print(dic)
# Out:
# header
# body

# %%
print(result['header'])
print(result['body'])

print(result['body']['items'][0]['DESC_KOR'])       # 바나나칩
print(result['body']['items'][0]['NUTR_CONT1'])
# Out:
# {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}
# {'pageNo': 1, 'totalCount': 1, 'numOfRows': 3, 'items': [{'DESC_KOR': '바나나칩', 'SERVING_WT': '30', 'NUTR_CONT1': '49.50', 'NUTR_CONT2': '5.40', 'NUTR_CONT3': '0.30', 'NUTR_CONT4': '3.00', 'NUTR_CONT5': '3.30', 'NUTR_CONT6': '0.60', 'NUTR_CONT7': '0.00', 'NUTR_CONT8': '2.70', 'NUTR_CONT9': '0.00', 'BGN_YEAR': '2017', 'ANIMAL_PLANT': '(유)돌코리아'}]}
# 바나나칩
# 49.50

# %% [markdown]
# #####[실습] 새우깡

# %%
# Python3 샘플 코드 #
import requests

# 일반 인증키 (Decoding) 사용
apikey = 'CTYRyVuDwSNng8WPJCY6Lm0A9JtQXyNRYn+7lI8FhtdmOgAF5g3dKjtS6AVkxJGU+dJXoZ2cmlEwbt7r6H1QsA=='

url = 'http://apis.data.go.kr/1471000/FoodNtrIrdntInfoService1/getFoodNtrItdntList1'

# 새우깡
#  (식품이름, 열량, 1회제공량, 구축년도) DataFrame 형태로 반환
params ={'serviceKey' : apikey,
         'desc_kor' : '새우깡',
         'type' : 'json' }

response = requests.get(url, params=params)

if response.status_code == 200:
    result = response.json()
    print(result)
else:
    print('실패 : ', response.status_code)
# Out:
# {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}, 'body': {'pageNo': 1, 'totalCount': 8, 'numOfRows': 10, 'items': [{'DESC_KOR': '과자,DHA새우깡', 'SERVING_WT': '30', 'NUTR_CONT1': '151.20', 'NUTR_CONT2': '18.12', 'NUTR_CONT3': '1.80', 'NUTR_CONT4': '7.35', 'NUTR_CONT5': 'N/A', 'NUTR_CONT6': '210.00', 'NUTR_CONT7': 'N/A', 'NUTR_CONT8': 'N/A', 'NUTR_CONT9': 'N/A', 'BGN_YEAR': '2006', 'ANIMAL_PLANT': '농심'}, {'DESC_KOR': '과자,DHA새우깡', 'SERVING_WT': '30', 'NUTR_CONT1': '45.36', 'NUTR_CONT2': '5.44', 'NUTR_CONT3': '0.54', 'NUTR_CONT4': '2.20', 'NUTR_CONT5': '0.30', 'NUTR_CONT6': '63.00', 'NUTR_CONT7': '0.00', 'NUTR_CONT8': '0.00', 'NUTR_CONT9': '0.00', 'BGN_YEAR': '2017', 'ANIMAL_PLANT': '농심'}, {'DESC_KOR': '새우깡', 'SERVING_WT': '30', 'NUTR_CONT1': '146.67', 'NUTR_CONT2': '20.00', 'NUTR_CONT3': '2.00', 'NUTR_CONT4': '6.67', 'NUTR_CONT5': '1.33', 'NUTR_CONT6': '180.00', 'NUTR_CONT7': '0.00', 'NUTR_CONT8': '2.13', 'NUTR_CONT9': '0.00', 'BGN_YEAR': '2015', 'ANIMAL_PLANT': '농심'}, {'DE
# ...

# %%
for item in result['body']['items']:
    print(item['DESC_KOR'], item['NUTR_CONT1'], item['SERVING_WT'], item['BGN_YEAR'])
# Out:
# 과자,DHA새우깡 151.20 30 2006
# 과자,DHA새우깡 45.36 30 2017
# 새우깡 146.67 30 2015
# 새우깡 44.00 30 2017
# 매운새우깡 146.67 30 2015
# 매운새우깡 44.00 30 2017
# 쌀새우깡 150.00 30 2015
# 쌀새우깡 45.00 30 2017

# %%
# 식품이름(DESC_KOR)
# 열량 (kcal) (NUTR_CONT1)
# 1회제공량 (g) (SERVING_WT)
# 구축년도 (BGN_YEAR)

df = pd.DataFrame(result['body']['items'])

# ===========================================================================
# Column Select
# Case1
df2 = df[['DESC_KOR', 'NUTR_CONT1', 'SERVING_WT', 'BGN_YEAR']]
# ===========================================================================


# ===========================================================================
# Column Rename
# Case1
df2.columns = ['식품이름', '열량 (kcal)', '1회제공량 (g)', '구축년도']
# Case2
newcols = {'DESC_KOR' : '식품이름', 'NUTR_CONT1' : '열량 (kcal)', 'SERVING_WT' : '1회제공량 (g)', 'BGN_YEAR' : '구축년도'}
df2.rename(columns=newcols, inplace=True)
# ===========================================================================

df2
# Out:
# <ipython-input-61-b65a9806a481>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns=newcols, inplace=True)
#         식품이름 열량 (kcal) 1회제공량 (g)  구축년도
# 0  과자,DHA새우깡    151.20        30  2006
# 1  과자,DHA새우깡     45.36        30  2017
# 2        새우깡    146.67        30  2015
# 3        새우깡     44.00        30  2017
# 4      매운새우깡    146.67        30  2015
# 5      매운새우깡     44.00        30  2017
# 6       쌀새우깡    150.00        30  2015
# 7       쌀새우깡     45.00        30  2017

# %% [markdown]
# ######함수로 구현

# %%
def Call_API():
    import requests
    import pandas as pd

    _desc_kor = str(input('식품이름을 입력해주세요=>'))
    print(f'{_desc_kor}를 입력하셨습니다')

    # 일반 인증키 (Decoding) 사용
    apikey = 'CTYRyVuDwSNng8WPJCY6Lm0A9JtQXyNRYn+7lI8FhtdmOgAF5g3dKjtS6AVkxJGU+dJXoZ2cmlEwbt7r6H1QsA=='

    url = 'http://apis.data.go.kr/1471000/FoodNtrIrdntInfoService1/getFoodNtrItdntList1'

    # 새우깡
    #  (식품이름, 열량, 1회제공량, 구축년도) DataFrame 형태로 반환
    params ={'serviceKey' : apikey,
             'desc_kor' : _desc_kor,
             'type' : 'json' }

    # 데이터 가져오기
    response = requests.get(url, params=params)

    if response.status_code == 200:
        result = response.json()   # response => json 형식으로 변환
        # print(result)
        if 'items' in result['body'].keys():
        # if result['body']['totalCount'] > 0:
            items = result['body']['items']

            # DataFrame으로 변환
            df = pd.DataFrame(items)
            # 컬럼 조회 (['DESC_KOR', 'NUTR_CONT1', 'SERVING_WT', 'BGN_YEAR'])
            df = df[['DESC_KOR', 'NUTR_CONT1', 'SERVING_WT', 'BGN_YEAR']]
            # 컬럼이름 변경 (['식품이름', '1회 제공량', '열량', '조사년도'])
            df.columns=['식품이름', '1회 제공량', '열량', '조사년도']

            return df
        else:
            # return 'f{_desc_kor}을 조회하지 못했습니다.'
            return []
    else:
        return '실패 : ', response.status_code

# %%
Call_API()
# Out:
# 식품이름을 입력해주세요=>새우깡
# 새우깡를 입력하셨습니다
#         식품이름  1회 제공량  열량  조사년도
# 0  과자,DHA새우깡  151.20  30  2006
# 1  과자,DHA새우깡   45.36  30  2017
# 2        새우깡  146.67  30  2015
# 3        새우깡   44.00  30  2017
# 4      매운새우깡  146.67  30  2015
# 5      매운새우깡   44.00  30  2017
# 6       쌀새우깡  150.00  30  2015
# 7       쌀새우깡   45.00  30  2017

# %% [markdown]
# ## 3.4 XML 데이터 처리

# %% [markdown]
# ###XML 데이터
#   - XML이란?
#     - XML(eXtensible Markup Language)는 데이터를 구조화하고 저장하기 위한 마크업 언어
#       - 데이터 교환에 대한 표준
#       - HTML과 유사하지만, 데이터의 표현에 중점을 두고 있음
#   - 특징
#     - 유연성
#       - 사용자 정의 태그를 사용하여 데이터를 표현할 수 있음
#     - 가독성
#       - 사람이 읽고 쓸 수 있는 형태로 데이터를 표현
#     - 데이터 교환
#       - 다양한 시스템 간에 데이터 교환을 용이하게 함

# %% [markdown]
# ###XML의 구조와 문법
# - XML의 주요 요소
#   - 루트 엘리먼트 : 모든 XML 문서에는 단 하나의 루트 엘리먼트가 있어야 함.
#   - 자식 엘리먼트 : 루트 엘리먼트 내에 포함된 엘리먼트
#   - 텍스트 노드 : 엘리먼트 내의 텍스트
# - sample.xml
# ```
# <?xml version="1.0" encoding="utf-8"?>
#  <customers>
#  <customer>
#  <name>홍길동</name>
#  <address>서울 강남구</address>
#  </customer>
#  <customer>
#  <name>고길동</name>
#  <address>서울 강북구</address>
#  </customer>
#  <customer>
#  <name>김길동</name>
#  <address>서울 서초구</address>
#  </customer>
#  </customers>
# ```

# %% [markdown]
# ###XML 데이터 읽기

# %% [markdown]
# ####파이썬 표준 라이브러리 xml 모듈
# ```
# import xml.etree.ElementTree as ET
# ```

# %%
import xml.etree.ElementTree as ET

# %% [markdown]
# #####String 으로부터 XML데이터 읽기

# %%
root = ET.fromstring(xml_data)
print(ET.tostring(root, encoding='utf-8').decode('utf-8'))

# %% [markdown]
# #####String 으로부터 데이터 읽기

# %%
root = ET.fromstring(xml_data)
print(f'루트 엘리먼트 : {root.tag}')

for child in root:
  print(child.tag)
  for item in child:
    print(f'{item.tag} : {item.text}')

# %% [markdown]
# #####XML파일로부터 데이터 읽기
#
# - sample.xml
# ```
# <?xml version="1.0" encoding="utf-8"?>
#  <customers>
#  <customer>
#  <name>홍길동</name>
#  <address>서울 강남구</address>
#  </customer>
#  <customer>
#  <name>고길동</name>
#  <address>서울 강북구</address>
#  </customer>
#  <customer>
#  <name>김길동</name>
#  <address>서울 서초구</address>
#  </customer>
#  </customers>
# ```

# %%
tree = ET.parse('sample.xml')

root = tree.getroot()

print(f'루트 엘리먼트 : {root.tag}')

for child in root:
  print(child.tag)
  for item in child:
    print(f'{item.tag} : {item.text}')

# %% [markdown]
# #####파이썬 표준 라이브러리 xml 모듈

# %% [markdown]
# - 검색하기
#   - find(path)
#     - 첫 번째 요소반환
#   - findall(path)
#     - 모든 요소반환
#   - findtext(path)
#     - 첫 번째 요소의 텍스트 반환
#   - path 스트링
#     - .**/**name
#       - 현재 노드의 바로 아래 자식 중에서 'name' 검색
#     - .**//**name
#       - 현재 노드의 모든 하위 경로에서 'name' 검색

# %% [markdown]
# #####파이썬 표준 라이브러리 xml모듈 이용하여 파일 저장하기

# %%
root = ET.Element('customers')
customer = ET.SubElement(root, 'customer')
name = ET.SubElement(customer, 'name')
name.text = '홍길동'
address = ET.SubElement(customer, 'address')
address.text = '서울 강남구'
customer = ET.SubElement(root, 'customer')
name = ET.SubElement(customer, 'name')
name.text = '고길동'
address = ET.SubElement(customer, 'address')
address.text = '서울 강북구'


tree = ET.ElementTree(root)
tree.write('output.xml', encoding='utf-8', xml_declaration=True)

# %% [markdown]
# ####lxml 라이브러리
# - 매우 빠른 파싱 속도를 제공하고, 대규모 XML 문서처리에 적합
# - 설치
# ```
# pip install lxml
# ```

# %%
from lxml import etree

# %% [markdown]
# ###### 문자열로 부터 데이터 읽기

# %%
from lxml import etree

root = etree.fromstring(xml_data)
print(f'루트 엘리먼트 : {root.tag}')

for child in root:
  print(child.tag)
  for item in child:
    print(f'{item.tag} : {item.text}')

# %% [markdown]
# ######파일로부터 XML파일 읽기

# %%
tree = etree.parse('sample.xml')

root = tree.getroot()
print(f'루트 엘리먼트 : {root.tag}')

for child in root:
  print(child.tag)
  for item in child:
    print(f'{item.tag} : {item.text}')

# %% [markdown]
# ######XML 파일에 쓰기

# %%
new_customer = etree.Element('customer')
name = etree.SubElement(new_customer, 'name')
name.text = '고길동'
address = etree.SubElement(new_customer, 'address')
address.text = '서울 강북구'

root.append(new_customer)

tree.write('modified_sample.xml', encoding='UTF-8', xml_declaration=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-60bd32dd9547> in <cell line: 7>()
#       5 address.text = '서울 강북구'
#       6
# ----> 7 root.append(new_customer)
#       8
#       9 tree.write('modified_sample.xml', encoding='UTF-8', xml_declaration=True)
#
# TypeError: append() argument must be xml.etree.ElementTree.Element, not lxml.etree._Element

# %% [markdown]
# ###웹 API를 사용하여 XML 데이터 수신

# %% [markdown]
# - RSS (Really Simple Syndication)
#   - Rich Site Summary 라고도 함.
#   - 뉴스나 블로그와 같이 컨텐츠 업데이트가 자주 일어나는 웹사이트에서, 업데이트 된 정보를 자동으로 사용자에게 제공하기 위한 서비스
#   - XML 데이터 형식

# %% [markdown]
# ####(예제) **XML데이터 처리**

# %%
import xml.etree.ElementTree as ET

# %% [markdown]
# ##### XML데이터 파일 읽기

# %% [markdown]
# sample.xml
# ```
# <?xml version="1.0" encoding="utf-8"?>
# <customers>
#     <customer>
#         <name>홍길동</name>
#         <address>서울 강남구</address>
#     </customer>
#     <customer>
#         <name>고길동</name>
#         <address>서울 강북구</address>
#     </customer>
#     <customer>
#         <name>김길동</name>
#         <address>서울 서초구</address>
#     </customer>
# </customers>
# ```

# %%
tree = ET.parse('sample.xml')
root = tree.getroot()
print(f'루트 엘리먼트 : {root.tag}')

print(ET.tostring(root, encoding='utf-8').decode('utf-8'))

# %%
name = root.find('.//name')
print(name)
print(f'{name.tag}:{name.text}')

name2 = root.findtext('.//name')
print(name2)

# %%
names = root.findall('.//name')
print(names)

# %%
print('len : ', len(names))
for name in names:
    print(type(name))
    print(f'{name.tag}:{name.text}')

# %% [markdown]
# #####웹에서 XML데이터 읽기

# %%
# %pip install lxml

# %% [markdown]
# ######jtbc 뉴스 크롤링

# %%
import requests
from lxml import etree
import xml.etree.ElementTree as ET

url = 'https://fs.jtbc.co.kr/RSS/culture.xml'
response = requests.get(url)

if response.status_code == 200:
    print(response.encoding)            # (ISO-8859-1) 수신된 데이터의 인코딩 방법
    print(response.apparent_encoding)   # (UTF-8-SIG) 추정 인코딩 방법

    print(type(response.content))       # <class 'bytes'>
    print(response.content)
    print(type(response.text))          # <class 'str'>
    print(response.text)

    #print(etree.fromstring(response.content))
    root = etree.fromstring(response.content)
else:
    print(response.status_code)
# Out:
# ISO-8859-1
# UTF-8-SIG
# <class 'bytes'>
# ...

# %%
# request 정보
print('response.request.method : ', response.request.method)
print('response.request.url : ', response.request.url)
print('response.request.headers : ', response.request.headers)
print('response.request.body : ', response.request.body)
# Out:
# response.request.method :  GET
# response.request.url :  https://fs.jtbc.co.kr/RSS/culture.xml
# response.request.headers :  {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
# response.request.body :  None

# %%
# response 정보
print('response.status_code : ', response.status_code)
print('response.headers : ', response.headers)
print('response.text : ', response.text)
# Out:
# response.status_code :  200
# response.headers :  {'Date': 'Tue, 23 Jul 2024 10:38:11 GMT', 'Content-Type': 'text/xml', 'Content-Length': '10821', 'Connection': 'keep-alive', 'Last-Modified': 'Tue, 23 Jul 2024 10:35:00 GMT', 'ETag': '"669f8754-2a45"', 'X-Cache-Status': 'BYPASS, BYPASS', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Server': 'nginx', 'Accept-Ranges': 'bytes, bytes', 'Keep-Alive': 'timeout=10'}
# ...

# %%
print(root)
print('root type : ', type(root))   # <class 'lxml.etree._Element'>
# Out:
# <Element rss at 0x78c5d5137ac0>
# root type :  <class 'lxml.etree._Element'>

# %%
import pandas as pd

items = root.findall('.//item')

lst = []

for i, item in enumerate(items):
    # print(f'{i}\r\n')
    # print(item.tag, item.text)

    # lst.append([item.findtext('.//title'), item.findtext('.//link')])
    lst.append([item.find('.//title').text[:30], item.find('.//link').text[:30]])

print('lst : \r\n', lst)

df = pd.DataFrame(lst, columns = ['제목', '링크'])
df
# Out:
# lst :
# ...

# %% [markdown]
# ######공공데이터 크롤링

# %%
import requests
import pandas as pd
from lxml import etree

# 일반 인증키 (Decoding) 사용
apikey = 'CTYRyVuDwSNng8WPJCY6Lm0A9JtQXyNRYn+7lI8FhtdmOgAF5g3dKjtS6AVkxJGU+dJXoZ2cmlEwbt7r6H1QsA=='

url = 'http://apis.data.go.kr/1471000/FoodNtrIrdntInfoService1/getFoodNtrItdntList1'

# 새우깡
#  (식품이름, 열량, 1회제공량, 구축년도) DataFrame 형태로 반환
params ={'serviceKey' : apikey,
         'desc_kor' : '바나나칩',
         'pageNo' : '1',
         'numOfRows' : '3',
         'bgn_year' : '2017',
         'animal_plant' : '(유)돌코리아',
         'type' : 'xml' }

# 데이터 가져오기
response = requests.get(url, params=params)

if response.status_code == 200:
    # result = response.json()
    # items = result['body']['items']
    # data = []
    # for item in items:
    #     # 'DESC_KOR', 'NUTR_CONT1', 'SERVING_WT', 'BGN_YEAR'
    #     data.append([item['DESC_KOR'], item['NUTR_CONT1'], item['SERVING_WT'], item['BGN_YEAR']])

    # df = pd.DataFrame(data, columns=['식품이름', '1회 제공량', '열량', '조사년도'])
    # print(df)

    print(response.encoding)            # (ISO-8859-1) 수신된 데이터의 인코딩 방법
    print(response.apparent_encoding)   # (UTF-8-SIG) 추정 인코딩 방법

    print(type(response.content))       # <class 'bytes'>
    print(response.content)
    print(type(response.text))          # <class 'str'>
    print(response.text)

    root = etree.fromstring(response.content)
else:
    print('실패 : ', response.status_code)
# Out:
# None
# utf-8
# <class 'bytes'>
# b'<?xml version="1.0" encoding="UTF-8"?>\n<response>\n<header>\n<resultCode>00</resultCode>\n<resultMsg>NORMAL SERVICE.</resultMsg>\n</header>\n<body>\n<numOfRows>3</numOfRows>\n<pageNo>1</pageNo>\n<totalCount>1</totalCount>\n<items>\n<item>\n<DESC_KOR>\xeb\xb0\x94\xeb\x82\x98\xeb\x82\x98\xec\xb9\xa9</DESC_KOR>\n<SERVING_WT>30</SERVING_WT>\n<NUTR_CONT1>49.50</NUTR_CONT1>\n<NUTR_CONT2>5.40</NUTR_CONT2>\n<NUTR_CONT3>0.30</NUTR_CONT3>\n<NUTR_CONT4>3.00</NUTR_CONT4>\n<NUTR_CONT5>3.30</NUTR_CONT5>\n<NUTR_CONT6>0.60</NUTR_CONT6>\n<NUTR_CONT7>0.00</NUTR_CONT7>\n<NUTR_CONT8>2.70</NUTR_CONT8>\n<NUTR_CONT9>0.00</NUTR_CONT9>\n<BGN_YEAR>2017</BGN_YEAR>\n<ANIMAL_PLANT>(\xec\x9c\xa0)\xeb\x8f\x8c\xec\xbd\x94\xeb\xa6\xac\xec\x95\x84</ANIMAL_PLANT>\n</item>\n</items>\n</body>\n</response>\n'
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
# <header>
# <resultCode>00</resultCode>
# <resultMsg>NORMAL SERVICE.</resultMsg>
# </header>
# <body>
# ...

# %%
items = root.findall('.//item')

lst = []

for i, item in enumerate(items):
    # print(f'{i}\r\n')
    # print(item.tag, item.text)

    # lst.append([item.findtext('.//DESC_KOR'), item.findtext('.//NUTR_CONT1')])
    lst.append([item.find('.//DESC_KOR').text, item.find('.//NUTR_CONT1').text])

print('lst : \r\n', lst)

df = pd.DataFrame(lst, columns = ['식품이름', '1회 제공량'])
df
# Out:
# lst :
#  [['바나나칩', '49.50']]
#    식품이름 1회 제공량
# 0  바나나칩  49.50

# %%
def Call_API():
    import requests
    import pandas as pd
    import xml.etree.ElementTree as ET
    from lxml import etree

    _desc_kor = str(input('식품이름을 입력해주세요=>'))
    print(f'{_desc_kor}를 입력하셨습니다')

    # 일반 인증키 (Decoding) 사용
    apikey = 'CTYRyVuDwSNng8WPJCY6Lm0A9JtQXyNRYn+7lI8FhtdmOgAF5g3dKjtS6AVkxJGU+dJXoZ2cmlEwbt7r6H1QsA=='

    url = 'http://apis.data.go.kr/1471000/FoodNtrIrdntInfoService1/getFoodNtrItdntList1'

    # 새우깡
    #  (식품이름, 열량, 1회제공량, 구축년도) DataFrame 형태로 반환
    params ={'serviceKey' : apikey,
             'desc_kor' : _desc_kor,
             'type' : 'xml' }

    # 데이터 가져오기
    response = requests.get(url, params=params)

    if response.status_code == 200:
        # bytes => str(문자열) 로 변환
        root = etree.fromstring(response.content)

        # 엘리먼트를 바이트 문자열로 변환한 후, 문자열로 변환
        str_enc = ET.tostring(root, encoding='utf-8').decode('utf-8')
        # print(str_enc)

        # <header>
        # <body>
        # <items>
        #   <item>
        #       <DESC_KOR>
        #       <NUTR_CONT1>
        #       ...
        #   <item>
        #       <DESC_KOR>
        #       <NUTR_CONT1>
        #       ...
        if root.findtext('.//totalCount') != '0':
            items = root.findall('.//item')             # item 엘리먼트 전체 찾기

            lst = []

            for i, item in enumerate(items):
                # print(f'{i}\r\n')
                # print(item.tag, item.text)

                lst.append([item.findtext('.//DESC_KOR'), item.findtext('.//NUTR_CONT1')])
                # lst.append([item.find('.//DESC_KOR').text, item.find('.//NUTR_CONT1').text])

            print('lst : \r\n', lst)
            df = pd.DataFrame(lst, columns = ['식품이름', '1회 제공량']).sort_values(by='1회 제공량', ascending=False)

            return df
        else:
            return _desc_kor + '을 조회하지 못했습니다.'
            #return []
    else:
        return '실패 : ', response.status_code

# %%
Call_API()
# Out:
# 식품이름을 입력해주세요=>새우깡
# 새우깡를 입력하셨습니다
# <response>
# <header>
# <resultCode>00</resultCode>
# <resultMsg>NORMAL SERVICE.</resultMsg>
# </header>
# <body>
# <numOfRows>10</numOfRows>
# <pageNo>1</pageNo>
# <totalCount>8</totalCount>
# <items>
# <item>
# <DESC_KOR>과자,DHA새우깡</DESC_KOR>
# <SERVING_WT>30</SERVING_WT>
# <NUTR_CONT1>151.20</NUTR_CONT1>
# <NUTR_CONT2>18.12</NUTR_CONT2>
# <NUTR_CONT3>1.80</NUTR_CONT3>
# <NUTR_CONT4>7.35</NUTR_CONT4>
# <NUTR_CONT5>N/A</NUTR_CONT5>
# <NUTR_CONT6>210.00</NUTR_CONT6>
# <NUTR_CONT7>N/A</NUTR_CONT7>
# <NUTR_CONT8>N/A</NUTR_CONT8>
# <NUTR_CONT9>N/A</NUTR_CONT9>
# <BGN_YEAR>2006</BGN_YEAR>
# <ANIMAL_PLANT>농심</ANIMAL_PLANT>
# </item>
# <item>
# <DESC_KOR>과자,DHA새우깡</DESC_KOR>
# <SERVING_WT>30</SERVING_WT>
# <NUTR_CONT1>45.36</NUTR_CONT1>
# <NUTR_CONT2>5.44</NUTR_CONT2>
# <NUTR_CONT3>0.54</NUTR_CONT3>
# <NUTR_CONT4>2.20</NUTR_CONT4>
# <NUTR_CONT5>0.30</NUTR_CONT5>
# <NUTR_CONT6>63.00</NUTR_CONT6>
# <NUTR_CONT7>0.00</NUTR_CONT7>
# ...

# %% [markdown]
# # 4. HTML을 이용한 웹 페이지 크롤링

# %% [markdown]
# ## 4.1. 웹 크롤링 기초
# - HTML 기본 구조와 태그 이해
# - BeautifulSoup 라이브러리 소개 및 설치
# - 간단한 웹 페이지 데이터 추출하기

# %% [markdown]
# ### HTML 기존구조와 태그 이해

# %% [markdown]
# - 웹(World Wide Web, www, w3) 이란 무엇인가?
#     - 인터넷을 통해 접근할 수 있는 정보 시스템
#     - 웹 브라우저를 통해 사용자들이 정보를 검색하고 공유할 수 있게 함.
#     - 인터넷 vs. 웹
#         - 인터넷 : 전 세계의 컴퓨터 네트워크를 연결하는 인프라
#         - 웹 : 이 인프라를 이용해 정보를 교환하는 서비스
# - 웹의 구성요소
#     - 클라이언트
#         - 웹 브라우저 : 사용자가 웹 페이지를 탐색할 수 있게 해주는 소프트웨어
#         - 웹 요청(Request) : 사용자가 웹 브라우저를 통해 서버에 요청하는 메시지
#     - 서버
#         - 웹 서버 : 클라이언트의 요청을 받아들여 적절한 웹 페이지를 반환하는 소프트웨어
#         - 데이터베이스 서버 : 데이터를 저장하고 관리하는 서버
#     - 네트워크
#         - 인터넷 : 전 세계의 컴퓨터 네트워크를 연결하는 시스템
#         - 프로토콜 : 통신 규칙으로, 웹에서는 주로 HTTP/HTTPS 를 사용함
# - 웹의 동작 원리
#     1. URL 입력
#         - 사용자가 웹 브라우저의 주소 창에 URL을 입력
#     2. DNS 조회
#         - 도메인 네임 시스템(DNS)을 통해 도메인 이름을 IP 주소로 변환
#     3. HTTP 요청
#         - 웹 브라우저가 해당 IP주소로 HTTP 요청을 보냄
#     4. 서버 처리
#         - 웹 서버가 요청을 처리하고, 필요한 경우 데이터베이스 서버와 통신함.
#     5. HTTP 응답
#         - 웹 서버가 요청에 대한 응답을 웹 브라우저에 반환
#     6. 렌더링
#         - 웹 브라우저가 HTML,CSS,JavaScript를 해석하여 사용자에게 웹 페이지를 표시
# - 웹 기술 개요
#     - HTTP (HyperText Transfer Protocol)
#         - 웹 브라우저와 서버 간의 통신을 규정하는 프로토콜
#     - HTML (HyperText Markup Language)
#         - 웹 페이지의 구조를 정의하는 마크업 언어
#     - CSS (Cascading Style Sheets)
#         - 웹 페이지의 스타일을 정의하는 언어
#     - JaveScript
#         - 웹 페이지에 동적 기능을 추가하는 프로그래밍 언어
# - HTTP의 개요
#     - 웹에서 정보를 주고 받기 위한 프로토콜
#     - 웹 브라우저와 웹 서버간의 통신을 가능하게 함.

# %% [markdown]
# - HTTP 요청 (Request) 메시지
#   - 요청라인 : 메서드, Path, HTTP 버전으로 구성
#   - 헤더(Header) : 요청에 대한 추가 정보 포함
#   - 본문(Body) : POST나 PUT메서드로 전송하는 데이터 (선택적)
#
#   - HTTP/2의 요청구조
#     - 요청 라인과 헤더가 별도로 작성되지 않음
#     - pseudo-header 필드로 요청 라인 정보 전달
#       - authority : WWW.NAVER.COM
#       - method : GET
#       - scheme : https
#       - path : /
#       - user-agent : Mozilla/5.0
#         - Request 라이브러리 사용 예
#           - response.request.method
#           - reponse.request.url
#           - reponse.request.headers
#           - reponse.request.body
#
# - HTTP 응답(Response) 메시지
#   - 상태라인 : HTTP버전, 상태코드, 상태 메시지로 구성
#   - 헤더(Header) : 응답에 대한 추가적인 정보를 포함
#   - 본문(Body) : 실제 응답 데이터 (HTML, JSON 등)
#         - Response 라이브러리 사용 예
#           - response.status_code
#           - response.headers
#           - response.text
#
# - HTTP 요청 메서드
#   - HTTP는 요청 메서드를 정의하며, 주어진 리소스에 수행하길 원하는 행동을 나타냄.
#     - GET : 서버로 부터 데이터를 조회
#       - GET을 사용하는 요청은 오직 데이터를 받기만 함.
#     - POST : 서버로 데이터를 전송할 때 사용
#     - PUT : 서버에 데이터를 전송하여 해당 리소스를 수정
#     - DELETE : 서버에서 해당 리소스를 삭제
#     - HEAD : GET과 유사하나, 응답 본문을 제외한 헤더만을 요청함.
#     - OPTIONS : 서버에서 지원하는 메소드를 조회

# %% [markdown]
# ### CSS 기초 개념

# %% [markdown]
# - CSS (Cascading Style Sheets) 란 무엇인가?
#     - HTML 문서의 스타일을 정의하는 언어
#     - 웹 페이지의 레이아웃, 색상, 폰트 등 시각적 요소를 꾸미기 위해 사용
# - 기본 문법
#     - CSS는 선택자(selector)와 선언(declaration) 으로 구성
#         - 선택자는 스타일을 적용할 HTML 요소를 선택
# ```
# 선택자 {
#     속성1 : 값1;
#     속성2 : 값2;
# }
#
# h1 {
#     color : blue;
#     font-size : 24px;
# }
# ```
#
# - 기본 문법
#     - CSS 적용하기
#         - 인라인 스타일 : 각 태그에 style 속성을 사용하여 직접 스타일 지정
#         ```
#         <h1 style="color:blue; font-size:24px;">제목1</h1>
#         ```

# %% [markdown]
# ## 4.2. 정적 데이터 수집

# %% [markdown]
# ###웹 페이지의 고정된 컨테츠를 수집하는 방법

# %% [markdown]
# ### BeautifulSoup 라이브러리
# - 웹 페이지에서 정보를 쉽게 스크래핑하는 라이브러리
#   - HTML 뿐만 아니라, XML파일 파싱도 쉽게 수행하는 라이브러리
#   - 구문 분석 트리를 사용하여, HTML 및 XML 파일을 탐색하고 검색하는 기능 제공
#   - 공식문서
#     - https://www.crummy.com/software/BeautifulSoup/bs4/doc/#quick-start
# - 주요특징
#   - HTML / XML 파싱
#   - 쉽고 직관적인 API
#   - 다양한 파서 지원(html.parser, lxml, xml 등)
# - 설치
#   ```
#   pip install beautifulSoup4
#   pip install bs4
#   ```
#   - parser 설치
#   ```
#   pip install lxml
#   ```

# %%
import requests

url = 'https://www.naver.com'
response = requests.get(url)

if response.status_code == 200:
  result = response.text
  print(result)
else:
  print('Failed : ', response.status_code)
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %% [markdown]
# ####BeautifulSoup 기본 사용

# %%
#%pip install beautifulSoup4
# %pip install bs4

# %%
from bs4 import BeautifulSoup

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# ####특정 태그 추출

# %%
# 특정 태그 추출
print('soup.title : ', soup.title)
print('soup.title.name : ', soup.title.name)

print('soup.title.string : ', soup.title.string)
print('soup.title.text : ', soup.title.text)

print('soup.title.parent.name : ', soup.title.parent.name)
# Out:
# soup.title :  <title>The Dormouse's story</title>
# soup.title.name :  title
# soup.title.string :  The Dormouse's story
# soup.title.text :  The Dormouse's story
# soup.title.parent.name :  head

# %% [markdown]
# #### 태그의 속성 접근

# %%
# 태그의 속성 접근
print('soup.p : ', soup.p)
print('soup.p["class"] : ', soup.p["class"])

print('soup.a : ', soup.a)
print('soup.a["class"] : ', soup.a["class"])
print('soup.a["href"] : ', soup.a["href"])
print('soup.a["id"] : ', soup.a["id"])
# Out:
# soup.p :  <p class="title"><b>The Dormouse's story</b></p>
# soup.p["class"] :  ['title']
# soup.a :  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# soup.a["class"] :  ['sister']
# soup.a["href"] :  http://example.com/elsie
# soup.a["id"] :  link1

# %% [markdown]
# #### find() 메서드 이용하기
# - 첫 번째로 발견된 태그를 반환

# %%
print('soup.find("a") : ', soup.find("a"))
print('soup.find("a", string="Lacie") : ', soup.find("a", string="Lacie"))
print('soup.find(id="link3) : ', soup.find(id = "link3"))
# Out:
# soup.find("a") :  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# soup.find("a", string="Lacie") :  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# soup.find(id="link3) :  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %% [markdown]
# #### fine_all() 메서드 이용하기
# - 모든 태그를 리스트로 반

# %%
print('soup.find_all("a") : ', soup.find_all("a"))
# Out:
# soup.find_all("a") :  [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# #### CSS 선택자를 사용하여 태그 선택

# %% [markdown]
# #####select_one() 메서드 이용하기
# - 처음으로 매치되는 태그 객체 하나만 반환

# %%
soup.select_one('p.title')
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %% [markdown]
# ####select() 메서드 이용하기
# - 매치되는 모든 태그를 리스트로 반환

# %%
soup.select("a.sister")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
links = soup.select("a.sister")
for link in links:
  print(link["href"])
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %% [markdown]
# #### 검색 된 태그의 attrs 사용하기

# %%
soup.select_one("a").attrs
# Out:
# {'href': 'http://example.com/elsie', 'class': ['sister'], 'id': 'link1'}

# %%
print(soup.select_one("a").attrs["href"])
print(soup.select_one("a").attrs["class"])
print(soup.select_one("a").attrs["id"])
# Out:
# http://example.com/elsie
# ['sister']
# link1

# %% [markdown]
# ---
# - 태그의 .string 과 .text 구분해서 사용하기
#   - 태그의 문자열을 추출할 때 사용
#   - .string : 태그가 단일 자식 텍스트 노드를 가질때 사용
#     - 태그 안에 또 다른 태그가 포함된 경우 None 반환
#   - .text : 태그와 그 모든 자식의 텍스트를

# %%
print('soup.select_one("a").string : ', soup.select_one("a").string)
print('soup.select_one("a").text : ', soup.select_one("a").text)
# Out:
# soup.select_one("a").string :  Elsie
# soup.select_one("a").text :  Elsie

# %% [markdown]
# ## 실습 (다음 뉴스 파싱)
# - 다음 뉴스 사이트
#   - https://news.daum.net
#   - 엑셀 저장하기
#   ```
#   pip install pandas
#   pip install openpyxl
#   ```

# %%
# %pip install openpyxl

# %%
import requests

url = 'https://news.daum.net'
response = requests.get(url)

if response.status_code == 200:
  result = response.text
  print(result)
else:
  print('Failed : ', response.status_code)
# Out:
# <!DOCTYPE html>
#
#
#
# <html lang="ko" class="os_unknown none unknown version_0 ">
# <head>
# <meta charset="utf-8">
# <meta name="referrer" content="always" />
#
# <meta property="og:author" content="Daum 뉴스" />
# <meta property="og:site_name" content="다음뉴스" />
# <meta property="og:title" content="다음뉴스 | 홈"/>
# <meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />
# <meta property="og:description" content="다음뉴스" />
# <meta property="og:url" content="https://news.daum.net/" />
# <link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">
#
# <title>다음뉴스 | 홈</title>
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/18ad2fd/style.css.merged.css" />
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/18ad2fd/calendar.css.merged.css" />
#
# <!--[if lte IE 8]>
# ...

# %%
from bs4 import BeautifulStoneSoup

soup = BeautifulSoup(result, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="os_unknown none unknown version_0" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="always" name="referrer">
#    <meta content="Daum 뉴스" property="og:author"/>
#    <meta content="다음뉴스" property="og:site_name"/>
#    <meta content="다음뉴스 | 홈" property="og:title"/>
#    <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
#    <meta content="다음뉴스" property="og:description"/>
#    <meta content="https://news.daum.net/" property="og:url"/>
#    <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
#    <title>
#     다음뉴스 | 홈
#    </title>
#    <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#    <link href="//t1.daumcdn.net/media/kraken/news/18ad2fd/style.css.merged.css" rel="stylesheet" type="text/css">
#     <link href="//t1.daumcdn.net/media/kraken/news/18ad2fd/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
#     <!--[if lte IE 8]>
# ...

# %%
items = soup.select(".list_newsissue > li")
print(type(items))
print(len(items), '\r\n', items)
# Out:
# <class 'bs4.element.ResultSet'>
# 20
#  [<li>
# <div class="item_issue" data-tiara-layer="headline1">
# <a class="wrap_thumb" data-tiara-custom="contentUniqueKey=hamny-20240724205002824&amp;clusterId=5970117,5969875,5600322,5939427,5590543,5969883,1691373&amp;clusterTitle=생활 &gt; 육아 (주요뉴스-섹션개편용),[섹션2024] 뉴스홈-주요뉴스,[언론사픽] 매거진_잡지류,[테스트] 언론사픽 3, 4번 포토 기사,[언론사픽] 주요뉴스,[섹션2024] 뉴스홈-최신뉴스,경상북도&amp;keywordType=NONE,NONE,NONE,NONE,NONE,NONE,NONE" data-tiara-id="20240724205002824" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20240724205002824">
# <img alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S192x120ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202407%2F24%2FKIZMOM%2F20240724205005078czzv.jpg&amp;scode=media2" 경북도,육아="" 근로="" 급여="" 단축="" 대상="" 보전="" 시="" 위한="" 확대"=""/>
# </a>
# <div class="cont_thumb">
# <span class="info_thumb">
# <span class="logo_cp">키즈맘</span>
# <span class="txt_category">생활</span>
# </span>
# ...

# %%
lst = []

for news in items:
  title = news.select_one(".tit_g > a").text.strip()
  link = news.select_one(".tit_g > a").attrs['href'].strip()
  corp = news.select_one(".logo_cp").text.strip()
  cate = news.select_one(".txt_category").text.strip()

  lst.append([title, link, corp, cate])

print(lst)
# Out:
# [['경북도,육아 위한 단축 근로 시 급여 보전 대상 확대', 'https://v.daum.net/v/20240724205002824', '키즈맘', '생활'], ['“세월호 보험금 보도, 도대체 왜···” 아들 잃은 아빠가 이진숙에 묻다', 'https://v.daum.net/v/20240724184514227', '경향신문', '사회'], ['전당대회 끝나자 \'한동훈 특검법\' 청문회 추진…여당 "축하인사를 이렇게" 반발', 'https://v.daum.net/v/20240724192551111', 'MBN', '정치'], ['공공택지 유찰···유찰···3기 신도시도 꼬인다', 'https://v.daum.net/v/20240724174858566', '서울경제', '경제'], ['이진숙 "\'법카\' 1만원도 사적으로 안 썼다…\'SNS 논란\'은 자연인 시절 발언"', 'https://v.daum.net/v/20240724194302550', '더팩트', 'IT/과학'], ['이은애 헌법재판관 후임 심사대상자 36명 압축', 'https://v.daum.net/v/20240724185003323', '더팩트', '사회'], ['법무장관, 김 여사 수사지휘 \'용산 소통\' 언급 의혹…법무부 "사실과 달라"', 'https://v.daum.net/v/20240724201406194', '뉴스1', '사회'], ['[단독] 심야 로켓배송 시작된 제주‥1주 만에 배송기사 쓰러졌다', 'https://v.daum.net/v/20240724203105483', 'MBC', '경제'], ['[집중취재M] "컨테이너를 못 구해요" 해상 물류 빨아들인 \'중국발 블랙홀\'', 'https://v.daum.net/v/20240724203405544', 'MBC', '경제'], ['윤 대통령, 한동훈 손잡고 "수고많았다"…\'삼겹살·상추쌈\' 대화합 만찬', 'https://v.daum.net/v/20240724201312175', '머니투데이', '정치'], ['
# ...

# %%
import pandas as pd

df = pd.DataFrame(lst, columns=['뉴스타이틀', '뉴스링크', '언론사', '카테고리'])
df
# Out:
#                                             뉴스타이틀  \
# 0                   경북도,육아 위한 단축 근로 시 급여 보전 대상 확대
# 1        “세월호 보험금 보도, 도대체 왜···” 아들 잃은 아빠가 이진숙에 묻다
# 2     전당대회 끝나자 '한동훈 특검법' 청문회 추진…여당 "축하인사를 이렇게" 반발
# 3                      공공택지 유찰···유찰···3기 신도시도 꼬인다
# 4   이진숙 "'법카' 1만원도 사적으로 안 썼다…'SNS 논란'은 자연인 시절 발언"
# 5                       이은애 헌법재판관 후임 심사대상자 36명 압축
# 6      법무장관, 김 여사 수사지휘 '용산 소통' 언급 의혹…법무부 "사실과 달라"
# 7             [단독] 심야 로켓배송 시작된 제주‥1주 만에 배송기사 쓰러졌다
# 8      [집중취재M] "컨테이너를 못 구해요" 해상 물류 빨아들인 '중국발 블랙홀'
# 9         윤 대통령, 한동훈 손잡고 "수고많았다"…'삼겹살·상추쌈' 대화합 만찬
# 10                세종보를 닫으려는 정부... 그래도, 우리는 승리해 왔다
# 11              "논밭에 왜 콘크리트가?".. 눈살 찌푸리게 하는 건설폐기물
# 12              "재활용 시설 의문의 폭발".. 노동계·정치권 '규명 촉구'
# 13       '완주-전주 통합건의' 제출.. "뭉쳐야 산다" VS "살던 대로 살자"
# 14          우크라이나, 열세 속 러시아와 접전…“장비 우세에도 露 진전 없어”
# 15                        OCI, 중국발 공급 과잉 여파에 '삐끗'
# 16           野 '김건희' 공세에 與 '김정숙' 맞불?…여야 정무위 '난타전'
# 17  신평 "한동훈 '가족 리스크', 문제 소지 많은 것 같아…尹이 한동훈 내칠 수도"
# ...

# %%
df.to_excel('daum_news.xlsx', index = False)

# %% [markdown]
# ## 실습 (멜론차트 파싱)
# - 멜론 사이트
#   - https://www.melon.com/chart/index.htm

# %%
import requests

url = 'https://www.melon.com/chart/index.htm'
header = {
    'User-Agent' : 'Mozilla/5.0',
    'Referer' : url
}

response = requests.get(url, headers=header)
result = response.text

# %% [markdown]
# ## 4.3. 동적 데이터 수집
