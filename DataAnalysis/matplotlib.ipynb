# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.plot([10, 20, 30, 40])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [12, 43, 25, 15])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('plotting')
plt.plot([10, 20, 30, 40])
plt.show()

# %%
# 범례의 위치를 지정하는 방법
# Ex) plt.legend(loc = 5)
# 1  - 오른쪽 상단
# 2  - 왼쪽 상단
# 3  - 왼쪽 하단
# 4  - 오른쪽 하단
# 5  - 오른쪽
# 6  - 왼쪽 중간
# 7  - 오른쪽 중간
# 8  - 중앙 하단
# 9  - 중앙 상단
# 10 - 정중앙
# 0  - 자동

# %%
import matplotlib.pyplot as plt
plt.title('legend')
plt.plot([10, 20, 30, 40], label='asc')     # 증가를 의마하는 asc 범례
plt.plot([40, 30, 20, 10], label='desc')    # 감소를 의미하는 desc 범례
plt.legend()
plt.show()

# %%
# 그래프 색상 바꾸기
# 색상을 표현할 때 기본적인 색에 대해서 다음과 같이 약자로 표기할 수도 있습니다.
# r - red
# g - green
# b - blue
# k - black
# y - yellow

# %%
import matplotlib.pyplot as plt
plt.title('color')   # 제목 설정

# 그래프 그리기
plt.plot([10, 20, 30, 40], color='skyblue', label='skyblue')
plt.plot([40, 30, 20, 10],'pink', label='pink')
plt.legend()   # 범례 표시
plt.show()

# %%
# 그래프 선 모양 바꾸기
# 색과 선모양을 '<색상><선모양>'을 동시에 적는 형태로 코드를 작성할 수도 있습니다.
#  plt.plot([1,2,3,4],'r--')

# %%
import matplotlib.pyplot as plt
plt.title('linestyle')    # 제목 설정

# 빨간색 dashed 그래프
plt.plot([10, 20, 30, 40], color='r', linestyle='--', label='dashed')
# 초록색 dotted 그래프
plt.plot([40, 30, 20, 10], color='g', ls=':', label='dotted')
plt.legend()    # 범례 표시
plt.show()

# %%
# 마커 모양 바꾸기
# 색상과 선 모양과 마커 모양을 동시에 설정하고 싶을때는 '<색상><마커모양><선모양>' 같이 할 수도 있다.
# plt.plot([1,2,3,4], 'r.--')

# %%
import matplotlib.pyplot as plt
plt.title('marker')   # 제목 설정
plt.plot([10, 20, 30, 40], 'r.', label='circle')   # 빨간색 원형 마커 그래프

plt.plot([40, 30, 20, 10], 'g^', label='triangle up')   # 초록색 삼각형 마커 그래프
plt.legend()   # 범례 표시
plt.show()

# %%
# hist()
import matplotlib.pyplot as plt
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %%
import matplotlib.pyplot as plt
import random

dice = []
for i in range(100):
    dice.append(random.randint(1, 6))
print(dice)
plt.hist(dice, bins=6)   # bins는 가로축의 구간개수를 설정한다.
plt.show()
# Out:
# [5, 1, 1, 5, 1, 4, 1, 3, 5, 6, 4, 4, 4, 1, 3, 6, 4, 1, 5, 4, 1, 4, 1, 2, 4, 6, 2, 6, 6, 3, 1, 4, 5, 2, 6, 3, 6, 4, 2, 2, 1, 5, 1, 5, 2, 6, 2, 3, 4, 2, 5, 6, 1, 2, 3, 1, 3, 4, 6, 3, 4, 2, 3, 6, 1, 3, 3, 1, 3, 6, 4, 1, 2, 1, 3, 2, 3, 1, 5, 3, 6, 4, 3, 6, 3, 1, 6, 4, 3, 5, 5, 5, 1, 3, 6, 5, 3, 5, 6, 4]
